# %%
# (Multi-File): Erzeuge Chatverläufe (STT/TTS) für alle JSONs im Ordner,
# gruppiert nach conversation.id. 
# und gib einen kombinierten DataFrame zurück.

import json
import re
from pathlib import Path
from typing import Any, Dict, List, Optional
import pandas as pd

# === Einstellungen anpassen ===
INPUT_DIR = Path("data/jaeger_exports/voice_ai_latency_v2_pilot_1/20251208_114421/json_traces")          # Ordner mit deinen JSON-Dateien
GLOB_PATTERN = "*.json"                # Muster für JSON-Dateien
LOCAL_TZ = "Europe/Berlin"             # Ausgabe in Berliner Zeit
SAVE_PER_CONVERSATION = False           # Pro Conversation-ID CSV speichern?
OUTPUT_DIR = INPUT_DIR / "exports"     # Zielordner für CSV-Exports
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)


# === Helpers ===
def tags_to_dict(tags: List[Dict[str, Any]]) -> Dict[str, Any]:
    return {t.get("key"): t.get("value") for t in (tags or [])}

def to_berlin_datetime(us_epoch: int) -> pd.Timestamp:
    ts = pd.to_datetime(us_epoch, unit="us", utc=True)
    return ts.tz_convert(LOCAL_TZ)

def sanitize_filename(name: str, maxlen: int = 120) -> str:
    name = re.sub(r"[^\w\-.]+", "_", str(name))
    return (name[:maxlen]).strip("._") or "conversation"

def load_spans_from_json(path: Path) -> List[Dict[str, Any]]:
    with path.open("r", encoding="utf-8") as f:
        data = json.load(f)
    if isinstance(data, dict):
        spans = data.get("spans", [])
    elif isinstance(data, list):
        spans = data
    else:
        spans = []
    for sp in spans:
        sp["_source_file"] = path.name
    return spans

def get_conversation_id(spans: List[Dict[str, Any]]) -> Optional[str]:
    """
    Extrahiert conversation.id NUR aus dem 'conversation'-Span.
    Erwartet tags:
      { "key": "conversation.id", "value": "<ID>" }
    """
    for sp in spans:
        if sp.get("operationName") == "conversation":
            t = tags_to_dict(sp.get("tags", []))
            cid = t.get("conversation.id")
            if cid:
                return str(cid)
    return None

def extract_rows_for_spans(spans: List[Dict[str, Any]], conversation_id: str) -> List[Dict[str, Any]]:
    rows: List[Dict[str, Any]] = []
    for span in spans:
        op = span.get("operationName")
        start_us = span.get("startTime")
        if start_us is None:
            continue

        if op not in ("stt", "tts"):
            continue

        tags = tags_to_dict(span.get("tags", []))

        if op == "stt":
            # nur finale STT (falls Flag vorhanden)
            is_final = tags.get("is_final")
            if is_final is not None and str(is_final).lower() not in ("true", "1", "yes"):
                continue
            text = (tags.get("transcript") or "").strip()
            role = "user"
        else:  # tts
            text = (tags.get("text") or "").strip()
            role = "assistant"

        if not text:
            continue

        rows.append({
            "conversation_id": conversation_id,
            "time": to_berlin_datetime(start_us),
            "role": role,
            "operation": op,
            "text": text,
            "spanID": span.get("spanID"),
            "duration_ms": round((span.get("duration") or 0) / 1000.0, 3),
            "_source_file": span.get("_source_file"),
        })
    return rows

# === Verarbeitung über alle Dateien ===
all_rows: List[Dict[str, Any]] = []
files = sorted(INPUT_DIR.glob(GLOB_PATTERN))
if not files:
    print(f"Keine Dateien gefunden in: {INPUT_DIR} mit Pattern: {GLOB_PATTERN}")

skipped = []
for fp in files:
    spans = load_spans_from_json(fp)
    conv_id = get_conversation_id(spans)
    if not conv_id:
        # -> Entweder überspringen oder Fehler werfen:
        # raise ValueError(f"Keine conversation.id im 'conversation'-Span gefunden: {fp}")
        skipped.append(fp.name)
        continue
    all_rows.extend(extract_rows_for_spans(spans, conv_id))

df_all = pd.DataFrame(all_rows)

if df_all.empty:
    print("Keine STT/TTS-Nachrichten mit gültiger conversation.id gefunden.")
else:
    # sortieren & msg# je conversation_id
    df_all = df_all.sort_values(["conversation_id", "time"]).reset_index(drop=True)
    df_all["msg#"] = df_all.groupby("conversation_id").cumcount() + 1

    # Spaltenreihenfolge
    cols = ["conversation_id", "msg#", "time", "role", "operation", "text", "spanID", "duration_ms", "_source_file"]
    df_all = df_all[[c for c in cols if c in df_all.columns]]

    # Optional: je Conversation-ID exportieren
    if SAVE_PER_CONVERSATION:
        for cid, df_conv in df_all.groupby("conversation_id", sort=False):
            out = OUTPUT_DIR / f"chat_{sanitize_filename(cid)}.csv"
            df_conv.to_csv(out, index=False)

# Info über übersprungene Dateien
if skipped:
    print("Übersprungen (keine conversation.id im 'conversation'-Span gefunden):")
    for s in skipped:
        print(" -", s)

# Ausgabe: kombinierter DataFrame mit allen Gesprächen
df_all
# Out:
# Übersprungen (keine conversation.id im 'conversation'-Span gefunden):
#  - 015f47038b37f91e93b8e3165e9a3fe2.json
#  - 04f539bf496de15bbd19360d2b3b7a3e.json
#  - 05189b6b961aa8b19c63433e01da300e.json
#  - 0540bfdfc5e9d3848960f0f3914c2ebb.json
#  - 06dc62605445b8f8f5060a4e1ca2621f.json
#  - 09b25fa2c1587201bd12293dabcda5ba.json
#  - 0b6d1942dbfb6a20c0d6e83a1b10a0b4.json
#  - 0b7152005940d3ad54232f954920ec74.json
#  - 0c092bb8565191434a2157913ef311c2.json
#  - 0e4d7442eb4bc80affba25dd4fddc0b7.json
#  - 0eb24dd79c30bc8e1a7ff1bec1c3be31.json
#  - 11980418caa48fa5b1931c33e6d68373.json
#  - 12a701147f5e5e4bda137e78e75c19ea.json
#  - 13cd7d64d420fe1e4b7fe4e887fba801.json
#  - 147ae91638dd51c458cc5966e3760c84.json
#  - 1e21f14e460747f860301b7612256c8a.json
#  - 1ef1b4b86684c93e0d810cac10c4135a.json
#  - 21373a47905db23d2b97d420ad81036c.json
#  - 21f4180dd28612782db28fbaddebddb6.json
#  - 24152ac7008f31e38944ff4cd86a06ad.json
#  - 24a132f92d9a959b481d0eac461ddc5b.json
#  - 2570310ec09296889c5ae4bfbfd71b18.json
#  - 25f4f052978b6025cfd944dd3f45b0af.json
#  - 2e85c1b94266f3616d42451883c211f1.json
#  - 2eac6a7ba026dfee11e5a71b79102436.json
#  - 2fb3ae912163177128ba768bac27eafd.json
# 13030             800    26 2025-11-16 18:28:13.010102+01:00  assistant
#
#       operation                                               text  \
# 0           tts                                         Guten Tag.
# 1           tts  Mein Name ist Kerstin – ich bin die digitale A...
# 2           tts  Ich helfe Ihnen jetzt dabei, einen Termin zu v...
# 3           tts  Vielen Dank, dass Sie an unserer wissenschaftl...
# 4           tts  Bitte geben Sie für dieses Gespräch nicht Ihre...
# ...         ...                                                ...
# 13026       stt                                           Sann af.
# 13027       tts  Bitte nennen Sie mir – gern mit einem Fantasie...
# 13028       stt                                      Max Mustaman.
# 13029       tts                         Vielen Dank, Max Mustaman.
# 13030       tts  Könnten Sie mir bitte Ihre Telefonnummer mitte...
#
#                  spanID  duration_ms                           _source_file
# 0      be8b6e8b0de22140      468.564  e9bc9f3f27ad7db63ba9e47d49f89bba.json
# 1      5b74ba9f02005d6a      137.182  e9bc9f3f27ad7db63ba9e47d49f89bba.json
# 2      00af3ed031d880a2      162.270  e9bc9f3f27ad7db63ba9e47d49f89bba.json
# 3      a69ee2f0e3c76ef9     1908.874  e9bc9f3f27ad7db63ba9e47d49f89bba.json
# 4      27b699a38e2a198a      117.855  e9bc9f3f27ad7db63ba9e47d49f89bba.json
# ...                 ...          ...                                    ...
# 13026  b41cc58ec5b09638        0.082  a6343fd2aeda7628e0f7a498540cd106.json
# 13027  b1d56f620c446cf6     1039.355  a6343fd2aeda7628e0f7a498540cd106.json
# 13028  e2f060c30aebddde        0.081  a6343fd2aeda7628e0f7a498540cd106.json
# 13029  8ba76e96d752a75c      510.015  a6343fd2aeda7628e0f7a498540cd106.json
# 13030  9446b3c347af4f53      131.269  a6343fd2aeda7628e0f7a498540cd106.json
#
# [13031 rows x 9 columns]

# %%
df_all[df_all["conversation_id"] == "390"]
# Out:
#      conversation_id  msg#                             time       role  \
# 4401             390     1 2025-10-30 18:44:51.207429+01:00  assistant
# 4402             390     2 2025-10-30 18:44:51.443736+01:00  assistant
# 4403             390     3 2025-10-30 18:44:51.547817+01:00  assistant
# 4404             390     4 2025-10-30 18:44:51.742902+01:00  assistant
# 4405             390     5 2025-10-30 18:44:51.866944+01:00  assistant
# 4406             390     6 2025-10-30 18:44:52.044848+01:00  assistant
# 4407             390     7 2025-10-30 18:44:52.159277+01:00  assistant
# 4408             390     8 2025-10-30 18:44:52.366429+01:00  assistant
# 4409             390     9 2025-10-30 18:44:52.504630+01:00  assistant
# 4410             390    10 2025-10-30 18:45:33.793629+01:00       user
# 4411             390    11 2025-10-30 18:45:41.505787+01:00  assistant
# 4412             390    12 2025-10-30 18:45:41.753797+01:00  assistant
# 4413             390    13 2025-10-30 18:45:53.231343+01:00       user
# 4414             390    14 2025-10-30 18:46:01.294576+01:00  assistant
# 4415             390    15 2025-10-30 18:46:01.867528+01:00  assistant
# 4416             390    16 2025-10-30 18:46:17.590421+01:00       user
# 4417             390    17 2025-10-30 18:46:26.513471+01:00  assistant
# 4418             390    18 2025-10-30 18:46:27.284817+01:00  assistant
# 4419             390    19 2025-10-30 18:46:42.082135+01:00       user
# 4420             390    20 2025-10-30 18:46:50.906953+01:00  assistant
# 4421             390    21 2025-10-30 18:47:02.480376+01:00       user
# 4422             390    22 2025-10-30 18:47:10.643393+01:00  assistant
# 4423             390    23 2025-10-30 18:47:10.868485+01:00  assistant
# 4424             390    24 2025-10-30 18:47:30.374570+01:00       user
# 4425             390    25 2025-10-30 18:47:40.982343+01:00  assistant
# 4426             390    26 2025-10-30 18:47:41.413293+01:00  assistant
# 4427             390    27 2025-10-30 18:47:53.600613+01:00       user
# 4428             390    28 2025-10-30 18:48:01.891043+01:00  assistant
# 4429             390    29 2025-10-30 18:48:02.005089+01:00  assistant
# 4430             390    30 2025-10-30 18:48:14.946524+01:00       user
# 4431             390    31 2025-10-30 18:48:23.236422+01:00  assistant
# 4432             390    32 2025-10-30 18:48:23.467823+01:00  assistant
# 4433             390    33 2025-10-30 18:48:23.619979+01:00  assistant
# 4434             390    34 2025-10-30 18:48:24.605337+01:00  assistant
# 4435             390    35 2025-10-30 18:48:24.706254+01:00  assistant
# 4436             390    36 2025-10-30 18:48:25.512878+01:00  assistant
# 4437             390    37 2025-10-30 18:48:54.181470+01:00       user
# 4438             390    38 2025-10-30 18:49:02.445871+01:00  assistant
# 4439             390    39 2025-10-30 18:49:02.624636+01:00  assistant
# 4440             390    40 2025-10-30 18:49:03.597693+01:00  assistant
# 4441             390    41 2025-10-30 18:49:03.785548+01:00  assistant
#
#      operation                                               text  \
# 4401       tts                                         Guten Tag.
# 4402       tts  Mein Name ist Kerstin – ich bin die digitale A...
# 4403       tts  Ich helfe Ihnen jetzt dabei, einen Termin zu v...
# 4404       tts  Vielen Dank, dass Sie an unserer wissenschaftl...
# 4405       tts  Bitte geben Sie für dieses Gespräch nicht Ihre...
# 4406       tts  Bitte nutzen Sie erfundene Daten wie zum Beisp...
# 4407       tts  Am Ende des Gesprächs nenne ich Ihnen eine dre...
# 4408       tts  Notieren Sie diese bitte und tragen Sie sie da...
# 4409       tts  Damit wir Sie bestmöglich einplanen können: Da...
# 4410       stt                                                Ja.
# 4411       tts                       Wie darf ich Sie ansprechen?
# 4412       tts  Bitte nennen Sie mir – gern mit einem Fantasie...
# 4413       stt                          Mein Name ist James Bond.
# 4414       tts                           Vielen Dank, James Bond.
# 4415       tts  Könnten Sie mir bitte Ihre Telefonnummer mitte...
# 4416       stt        Ja, mein Telefonnummer ist 49 1555 55 6969.
# 4417       tts                           Vielen Dank, James Bond.
# 4418       tts  Könnten Sie mir bitte den Grund für Ihren Besu...
# 4419       stt  Ich habe vier Tage Kopfschmerzen und ich kann ...
# 4420       tts  Sie haben angegeben, dass Sie wegen vier Tagen...
# 4421       stt                               Ja, das ist korrekt.
# 4422       tts                   Vielen Dank für die Bestätigung.
# 4423       tts  Ich kann Ihnen folgende Termine anbieten: \n\n...
# 4424       stt                   Am 31. Oktober um 11 Uhr ist OK.
# 4425       tts  Sie haben den einunddreißigsten Oktober um elf...
# 4426       tts  Sie haben den einunddreißigsten Oktober um elf...
# 4427       stt                                    Ja, das stimmt.
# 4428       tts                   Vielen Dank für die Bestätigung.
# 4429       tts  Sie haben angegeben, dass Sie wegen vier Tagen...
# 4430       stt                               Ja, das ist korrekt.
# 4431       tts                                       Vielen Dank.
# 4432       tts                            Der Termin ist notiert.
# 4433       tts  Ihr Termin ist am einunddreißigsten Oktober um...
# 4434       tts  Ich bleibe noch in der Leitung, falls Sie weit...
# 4435       tts       Ihre persönliche Umfrage-Nummer lautet: 390.
# 4436       tts  Bitte notieren Sie diesen Code und tragen Sie ...
# 4437       stt                                       Vielen Dank.
# 4438       tts                                    Gern geschehen!
# 4439       tts       Ihre persönliche Umfrage-Nummer lautet: 390.
# 4440       tts  Bitte notieren Sie diesen Code und tragen Sie ...
# 4441       tts                                   Auf Wiederhören!
#
#                 spanID  duration_ms                           _source_file
# 4401  244d2bcaec4a4653      235.768  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4402  24a5f2c5e73bcf12      103.635  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4403  5ee3545626e04500      194.799  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4404  ac635075ef655dc0      123.653  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4405  5292a57a8d1695b9      177.604  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4406  36473803d49c995b      113.980  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4407  d8a0f1ea7e87ad8d      206.771  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4408  046c24f2fddc7bd7      137.730  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4409  b589f7d8aaf9db66      181.931  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4410  e86f256b02bdb14e        0.056  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4411  c5fd5fc327735cde      246.847  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4412  73d863de1cb80c25      149.222  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4413  0143d47d7b58ce72        0.083  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4414  b8c8eacebb6cf99e      571.990  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4415  4d3f55288d9e0e10      157.345  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4416  e1e8a11467f67eba        0.065  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4417  9eb084ac13b73c1d      770.641  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4418  85b7af8bada674bc      739.681  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4419  24135516d2257fb8        0.092  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4420  2f4536c8d2caf8b0     1310.104  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4421  a67aa6db79cfcd81        0.055  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4422  cc1d9007c410f444      224.329  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4423  d9bc2df12cdba501     2858.822  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4424  450dba035488b2d8        0.064  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4425  378270a59149e4aa      310.815  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4426  8bca2d8378b00dba      120.018  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4427  1c6e109bd78b579b        0.162  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4428  6aa92a46faec9918      113.406  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4429  68c27f27a5375508     1299.407  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4430  4c161621cc451c42        0.062  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4431  267200b97abaae66      230.765  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4432  524ff34965c1f6ad      151.706  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4433  281cfee0dc54ccd0      984.764  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4434  cc6976b2acaf1537      100.275  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4435  80adbc3af3b654c0      806.058  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4436  41a550243fc45d4f      158.708  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4437  31b2c2baebbc0431        0.083  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4438  bb0e21609956c21f      177.861  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4439  ecf7da4a503b3b8a      972.503  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4440  d86fcc59e88c42c0      187.270  3b753c3d68a8a4c6988a766a0f6147ac.json
# 4441  872fb1ecd6a302ee      153.681  3b753c3d68a8a4c6988a766a0f6147ac.json

# %%
import os; print(os.getcwd())
# Out:
# d:\Desktop\data_merge\mycode
